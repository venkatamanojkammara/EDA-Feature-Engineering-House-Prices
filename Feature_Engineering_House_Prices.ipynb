# %% [markdown]
# Now we will start the Feature Engineering part. Now here we will perform the following steps.
# 1. Missing Values
# 2. Temporal Variables
# 3. Categorical Variables
# 4. Standardise the vales of the variables.

# %% [markdown]
# Import the necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# Now read the dataset. into a variable.

# %%
dataset=pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# Here in this caggle dataset we have the train data and as well as test data. Here now we will do the train_test_split to avoid the data leakage by using the sklearn.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(dataset,dataset['SalePrice'],test_size=0.1,random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %% [markdown]
# Now we need to find the missing value categorical features and then we will handle them to replace the value.

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1 and dataset[feature].dtype=='O']
categorical_features
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
len(categorical_features)
# Out:
# 15

# %% [markdown]
# now will see the percentage of the missing values in the above categorical features correspondingly

# %%
for feature in categorical_features:
  print(feature, np.round(dataset[feature].isnull().mean(),4), dataset[feature].isnull().sum())
# Out:
# Alley 0.9377 1369
# MasVnrType 0.5973 872
# BsmtQual 0.0253 37
# BsmtCond 0.0253 37
# BsmtExposure 0.026 38
# BsmtFinType1 0.0253 37
# BsmtFinType2 0.026 38
# FireplaceQu 0.4726 690
# GarageType 0.0555 81
# GarageFinish 0.0555 81
# GarageQual 0.0555 81
# GarageCond 0.0555 81
# PoolQC 0.9952 1453
# Fence 0.8075 1179
# MiscFeature 0.963 1406

# %% [markdown]
# now we will replace the missing nan values with some other label, let say 'missing'

# %%
def replace_categorical_features(dataset,categorical_features):
  data=dataset.copy()
  data[categorical_features]=data[categorical_features].fillna("Missing")
  return data

dataset=replace_categorical_features(dataset,categorical_features)

# %% [markdown]
# now lets check if there were any missing nan vales in the categorical values.

# %%
dataset[categorical_features].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# upto now the handling part of categorical features was completed. now its turn for the numerical features.

# %%
numerical_features=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1 and dataset[feature].dtype !='O']
numerical_features
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# now check for the mean percentage of the missing nan values.

# %%
for feature in numerical_features:
  print(feature,np.round(dataset[feature].isnull().mean(),4),dataset[feature].isnull().sum())
# Out:
# LotFrontage 0.1774 259
# MasVnrArea 0.0055 8
# GarageYrBlt 0.0555 81

# %% [markdown]
# Now its turn to fill the missing vaues. as we know that there were some outliers in the numerical features hence we need to consider the median or mode.
# creates new column and there place, 1 for corresponding if there were any missing values and 0 for no nan values.

# %%
for feature in numerical_features:
  median_value = dataset[feature].median()
  dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
  dataset[feature].fillna(median_value, inplace=True)

# %% [markdown]
# now we will check, if there were any null values.

# %%
dataset[numerical_features].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage       0
# LotArea           0
#                  ..
# SaleCondition     0
# SalePrice         0
# LotFrontagenan    0
# MasVnrAreanan     0
# GarageYrBltnan    0
# Length: 84, dtype: int64

# %%
dataset.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave  Missing      Reg
# 1     2          20       RL         80.0     9600   Pave  Missing      Reg
# 2     3          60       RL         68.0    11250   Pave  Missing      IR1
# 3     4          70       RL         60.0     9550   Pave  Missing      IR1
# 4     5          60       RL         84.0    14260   Pave  Missing      IR1
# ..  ...         ...      ...          ...      ...    ...      ...      ...
# 95   96          60       RL         69.0     9765   Pave  Missing      IR2
# 96   97          20       RL         78.0    10264   Pave  Missing      IR1
# 97   98          20       RL         73.0    10921   Pave  Missing      Reg
# 98   99          30       RL         85.0    10625   Pave  Missing      Reg
# 99  100          20       RL         77.0     9320   Pave  Missing      IR1
#
# ...

# %%
features_with_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1]
features_with_nan
# Out:
# []

# %% [markdown]
# As we know that there were some temporal variables, ie. data and time variables. in this case we have year variables.
# Now we will find the year differnce for the YrSold and the other year features.

# %%
dataset[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
  dataset[feature]=dataset['YrSold']-dataset[feature]

dataset[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# As there were many numerical features and they were skewed so to make in into normal we will apply the log normal distrubution to the features that do not zero in them.

# %%
num_features=['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']
for feature in num_features:
  dataset[feature]=np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1   2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2   3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3   4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4   5          60       RL     1.488584  2.258133   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# Now we will find the rare categorical features.
# (The categorical variables values that are present less than 1% of the feature are rare categorical features).
# Here we will find those type of rare categorical features and replace them with a new label to get the better results

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtype == 'O']
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
for feature in categorical_features:
  temp=dataset.groupby(feature)["SalePrice"].count()/len(dataset)
  temp_df=temp[temp>0.01].index
  dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],"RareVar")

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1   2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2   3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3   4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4   5          60       RL     1.488584  2.258133   Pave  Missing      IR1
# 5   6          50       RL     1.491251  2.257064   Pave  Missing      IR1
# 6   7          20       RL     1.462674  2.221235   Pave  Missing      Reg
# 7   8          60       RL     1.443172  2.224389   Pave  Missing      IR1
# 8   9          50       RM     1.369104  2.165541   Pave  Missing      Reg
# 9  10         190       RL     1.364055  2.187391   Pave  Missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %% [markdown]
# Here we have sucessfully completed the Feature Engineering Part. and Now this data or the data set is perferctly eligible for applying the ML algorithum.
